# %%
import warnings
import time
import itertools
from typing import Dict, List

import requests
from fake_headers import Headers
from bs4 import BeautifulSoup
from returns.io import IO
from lxml import html

'''
Общий алгоритм работы
---------------------
-> Определь неизменяемые входные данные ({url, domain, headers{browser,os,headers}}).
-> Получить общее количество страниц пагинации с данными (товарами)
-> Получить url всех страниц пагинации (в случае e-katalog это порядковый номер страницы)
-> Получить список списков со всеми url конкретного товарова
-> Распаковать все списки в один список.
-> Добавить ко всем url домен, как итог список окончательных ссылок к товару.
_____________________

# %%
warnings.filterwarnings('ignore')

# %%
class imdict(dict):
    def __hash__(self):
        return id(self)

    def _immutable(self, *args, **kws):
        raise TypeError('object is immutable')

    __setitem__ = _immutable
    __delitem__ = _immutable
    clear       = _immutable
    update      = _immutable
    setdefault  = _immutable
    pop         = _immutable
    popitem     = _immutable

# %%
data = imdict({'URL':'https://www.e-katalog.ru/list/190/',
               'DOMAIN': 'https://www.e-katalog.ru',
               'headers': {'browser':"chrome", 
                          'os':"win",
                          'headers': True}})

# %%
def generate_headers(headers_setting: Dict) -> IO[Dict]:
    '''
    Генерирует html заголовки запросов. В данном случае фейковые.
    '''
    #TODO Расширить количество аргументов.

    return Headers(
                   browser = headers_setting['browser'],
                   os = headers_setting['os'],
                   headers = headers_setting['headers']
                   ).generate()

# %%
def get_page_html(url: str, verify: bool = False):
    '''На основе url получает всю html страницы, без потверждения ssl(опционально)'''

    return BeautifulSoup(requests.get(url, verify=verify).content, 'html.parser')

# %%
def get_product_amount_page(url: str, headers: Dict = generate_headers(data['headers'])) -> IO[int]:
    '''
    Возвращает общее количество страниц для конкретного типа продукта
    | ---
    | url = базовый url страницы конкретного продукта (data['url'])
    | headers = Шапка html запроса в формате словаря.
    | ---
    '''

    def page_count(tree):
        return tree.xpath('//div[@class="ib page-num"]//a[last()]/text()')   

    return int(page_count(html.fromstring(requests.get(url, headers = headers).content))[0])

# %%
def collect_product_pages(url: str, pages_count: int) -> List[str]:
    '''
    *Получает список url страниц с товарами.*
    | ---
    | url = базовый url страницы конкретного продукта (data['url'])
    | pages_count = Общее количество страниц для продукта.
    | ---
    '''
    return list(map(lambda x: url + f"{x}/", range(1, pages_count)))

# %%
def collect_url_from_page(page_url: str, headers = generate_headers(data['headers']), sleep: int = 1) -> List[str]:
    '''
    *Получает все url продуктов со страницы(получает список страницы), возвращает список url*
    | ---
    | page_url = url страницы со товармаи
    | headers = Шапка html запроса в формате словаря
    | sleep = Время задержки после запроса
    | ---
    '''

    def get_product_url(tree):
        return tree.xpath("//a[@class='model-short-title no-u no-u']/@href") 
    
    time.sleep(sleep)
    return get_product_url(html.fromstring(requests.get(page_url, headers=headers).content))

# %%
pages_urls = collect_product_pages(data['URL'], get_product_amount_page(
                                                          data['URL'],
                                                          generate_headers(data['headers'])))

# %%
all_url_product = list(itertools.chain(*list(map(collect_url_from_page,urls)))) # Распоковка всех списков

# %%
full_url_path_to_product = list((map(lambda x: data['DOMAIN'] + x, all_urls)))
# Out:
# ['https://www.e-katalog.ru/WD-WD141KRYZ.htm',
#  'https://www.e-katalog.ru/WD-WUH721414ALE6L4.htm',
#  'https://www.e-katalog.ru/TOSHIBA-HDTP220EK3CA.htm',
#  'https://www.e-katalog.ru/TOSHIBA-HDWT380UZSVA.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST8000NM0055.htm',
#  'https://www.e-katalog.ru/WD-WD20EFZX.htm',
#  'https://www.e-katalog.ru/TRANSCEND-TS4TSJ25H3P.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST18000NM000J.htm',
#  'https://www.e-katalog.ru/TOSHIBA-MG08ACA16TE.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST10000VE0008.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST1000LM048.htm',
#  'https://www.e-katalog.ru/TOSHIBA-HDWL110EZSTA.htm',
#  'https://www.e-katalog.ru/TRANSCEND-TS4TSJ25M3S.htm',
#  'https://www.e-katalog.ru/WD-WD121KFBX.htm',
#  'https://www.e-katalog.ru/WD-WD30EZRX.htm',
#  'https://www.e-katalog.ru/TOSHIBA-HDTP340EK3CA.htm',
#  'https://www.e-katalog.ru/TOSHIBA-MG07SCA14TE.htm',
#  'https://www.e-katalog.ru/TOSHIBA-HDWN180EZSTA.htm',
#  'https://www.e-katalog.ru/WD-HUS726T4TALE6L4.htm',
#  'https://www.e-katalog.ru/SEAGATE-STHP4000400.htm',
#  'https://www.e-katalog.ru/WD-WD1003FZEX.htm',
#  'https://www.e-katalog.ru/WD-WD10SPZX.htm',
#  'https://www.e-katalog.ru/SEAGATE-STEF4000400.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST1000LM049.htm',
#  'https://www.e-katalog.ru/HITACHI-HUH721212ALE604.htm',
#  'https://www.e-katalog.ru/WD-WD4005FZBX.htm',
#  'https://www.e-katalog.ru/DELL-400-ATJV.htm',
#  'https://www.e-katalog.ru/HITACHI-HUH721010ALE604.htm',
#  'https://www.e-katalog.ru/SEAGATE-STGG8000400.htm',
#  'https://www.e-katalog.ru/SEAGATE-STJL5000400.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST10000NM0086.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST16000NE000.htm',
#  'https://www.e-katalog.ru/LENOVO-7XB7A00053.htm',
#  'https://www.e-katalog.ru/WD-WDBBGB0040HBK.htm',
#  'https://www.e-katalog.ru/SILICON-POWER-SP050TBPHDA85S3S.htm',
#  'https://www.e-katalog.ru/WD-WD10JFCX.htm',
#  'https://www.e-katalog.ru/LACIE-STHG5000400.htm',
#  'https://www.e-katalog.ru/TOSHIBA-MG06SCA10TE.htm',
#  'https://www.e-katalog.ru/LENOVO-4XB7A14101.htm',
#  'https://www.e-katalog.ru/SEAGATE-STGD4000400.htm',
#  'https://www.e-katalog.ru/WD-WD20EFAX.htm',
#  'https://www.e-katalog.ru/SEAGATE-STEA4000407.htm',
#  'https://www.e-katalog.ru/A-DATA-AHD650-1TU31-CBK.htm',
#  'https://www.e-katalog.ru/WD-WDBJRT0040BBK-WESN.htm',
#  'https://www.e-katalog.ru/TOSHIBA-DT01ACA300.htm',
#  'https://www.e-katalog.ru/HITACHI-HTS725050A7E630.htm',
#  'https://www.e-katalog.ru/A-DATA-AHV300-4TU31-CBK.htm',
#  'https://www.e-katalog.ru/SEAGATE-STHN2000400.htm',
#  'https://www.e-katalog.ru/WD-HUH721010ALE604.htm',
#  'https://www.e-katalog.ru/SEAGATE-STHH2000400.htm',
#  'https://www.e-katalog.ru/SILICON-POWER-SP500GBPHDA60S3K.htm',
#  'https://www.e-katalog.ru/TOSHIBA-MG04ACA600E.htm',
#  'https://www.e-katalog.ru/TOSHIBA-MG04SCA60EE.htm',
#  'https://www.e-katalog.ru/TOSHIBA-HDTX110ESCAA.htm',
#  'https://www.e-katalog.ru/A-DATA-AHD710P-2TU31-CBK.htm',
#  'https://www.e-katalog.ru/TOSHIBA-HDTX110EK3AA.htm',
#  'https://www.e-katalog.ru/WD-HUS722T1TALA604.htm',
#  'https://www.e-katalog.ru/TOSHIBA-MG04SCA400E.htm',
#  'https://www.e-katalog.ru/A-DATA-AHD330-5TU31-CBK.htm',
#  'https://www.e-katalog.ru/HITACHI-HUS726T6TALE6L4.htm',
#  'https://www.e-katalog.ru/TRANSCEND-TS4TSJ25M3C.htm',
#  'https://www.e-katalog.ru/TRANSCEND-TS2TSJ25A3K.htm',
#  'https://www.e-katalog.ru/WD-WD10JPLX.htm',
#  'https://www.e-katalog.ru/SEAGATE-STDR2000200.htm',
#  'https://www.e-katalog.ru/DELL-401-ABHX.htm',
#  'https://www.e-katalog.ru/DELL-400-BEII.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST4000VX000.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST1000DM003.htm',
#  'https://www.e-katalog.ru/HITACHI-HUS722T2TALA604.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST1800MM0129.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST4000VM000.htm',
#  'https://www.e-katalog.ru/WD-HUH721212AL5204.htm',
#  'https://www.e-katalog.ru/HITACHI-HDS723030ALA640.htm',
#  'https://www.e-katalog.ru/WD-WDBA5G0030BBK-WESN.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST8000NM0075.htm',
#  'https://www.e-katalog.ru/WD-WDBA2W0020BBK-WESN.htm',
#  'https://www.e-katalog.ru/LACIE-STGB16000400.htm',
#  'https://www.e-katalog.ru/WD-WDBFBE0240JBK.htm',
#  'https://www.e-katalog.ru/A-DATA-AHV320-2TU31-CBK.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST2000DX002.htm',
#  'https://www.e-katalog.ru/LACIE-STHA4000800.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST500DM002.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST1000DX001.htm',
#  'https://www.e-katalog.ru/A-DATA-AHV620S-1TU31-CBL.htm',
#  'https://www.e-katalog.ru/WD-WD3000FYYZ.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST500LX025.htm',
#  'https://www.e-katalog.ru/TOSHIBA-MQ01ABD050.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST3300657SS.htm',
#  'https://www.e-katalog.ru/TOSHIBA-HDWU110UZSVA.htm',
#  'https://www.e-katalog.ru/WD-WD5000AAKX.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST1000LM035.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST4000DM000.htm',
#  'https://www.e-katalog.ru/WD-WDBC3C0020BBL.htm',
#  'https://www.e-katalog.ru/3Q-3QHDD-T292M-500.htm',
#  'https://www.e-katalog.ru/WD-WDBVPL0010BBK.htm',
#  'https://www.e-katalog.ru/TOSHIBA-MQ01ABF050.htm',
#  'https://www.e-katalog.ru/SAMSUNG-HD322GJ.htm',
#  'https://www.e-katalog.ru/TRANSCEND-TS2TSJ25MC.htm',
#  'https://www.e-katalog.ru/WD-WD20NPVX.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST3500312CS.htm',
#  'https://www.e-katalog.ru/HITACHI-HUS724040ALE640.htm',
#  'https://www.e-katalog.ru/LACIE-STFR2000800.htm',
#  'https://www.e-katalog.ru/LACIE-STFR5000800.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST33000650NS.htm',
#  'https://www.e-katalog.ru/HITACHI-HDS721616PLA380.htm',
#  'https://www.e-katalog.ru/DELL-400-ATJD.htm',
#  'https://www.e-katalog.ru/DELL-400-ATKV.htm',
#  'https://www.e-katalog.ru/TOSHIBA-HDTW110EB3AA.htm',
#  'https://www.e-katalog.ru/SILICON-POWER-SP010TBPHDS03S3K.htm',
#  'https://www.e-katalog.ru/HITACHI-HTS545050A7E380.htm',
#  'https://www.e-katalog.ru/HP-R0Q21A.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST4000DM006.htm',
#  'https://www.e-katalog.ru/TOSHIBA-HDTB420EKCAA.htm',
#  'https://www.e-katalog.ru/TRANSCEND-TS2TSJ25C3S.htm',
#  'https://www.e-katalog.ru/TOSHIBA-MQ01ACF050.htm',
#  'https://www.e-katalog.ru/SILICON-POWER-SP020TBPHDA80S3B.htm',
#  'https://www.e-katalog.ru/TOSHIBA-MG03ACA300.htm',
#  'https://www.e-katalog.ru/WD-WD20EURS.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST2000VX000.htm',
#  'https://www.e-katalog.ru/HITACHI-HUA722010CLA330.htm',
#  'https://www.e-katalog.ru/TOSHIBA-HDTB305EK3AA.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST1000NX0333.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST4000NM0023.htm',
#  'https://www.e-katalog.ru/HITACHI-HUS156060VLS600.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST9500325AS.htm',
#  'https://www.e-katalog.ru/HITACHI-HUS154530VLS300.htm',
#  'https://www.e-katalog.ru/TOSHIBA-AL15SEB24EQ.htm',
#  'https://www.e-katalog.ru/TOSHIBA-HDTD310EK3DA.htm',
#  'https://www.e-katalog.ru/TOSHIBA-MG03SCA400.htm',
#  'https://www.e-katalog.ru/TOSHIBA-HDTCA40EK3CA.htm',
#  'https://www.e-katalog.ru/HITACHI-HUS726040ALE614.htm',
#  'https://www.e-katalog.ru/WD-WD10EARS.htm',
#  'https://www.e-katalog.ru/LACIE-STFY8000400.htm',
#  'https://www.e-katalog.ru/VERBATIM-53023.htm',
#  'https://www.e-katalog.ru/LENOVO-4XB0F28665.htm',
#  'https://www.e-katalog.ru/WD-WD1000DHTZ.htm',
#  'https://www.e-katalog.ru/SILICON-POWER-SP020TBPHDA75S3S.htm',
#  'https://www.e-katalog.ru/DELL-400-BJRS.htm',
#  'https://www.e-katalog.ru/SEAGATE-STJF4000400.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST4000VN0001.htm',
#  'https://www.e-katalog.ru/SILICON-POWER-SP010TBPHDA65S3K.htm',
#  'https://www.e-katalog.ru/HP-M0S90A.htm',
#  'https://www.e-katalog.ru/DELL-400-AMPG.htm',
#  'https://www.e-katalog.ru/SILICON-POWER-SP020TBPHDD3SS3K.htm',
#  'https://www.e-katalog.ru/WD-WDBA2D0020BBL.htm',
#  'https://www.e-katalog.ru/HITACHI-HTS723232A7A364.htm',
#  'https://www.e-katalog.ru/SILICON-POWER-SP010TBPHDA30S3K.htm',
#  'https://www.e-katalog.ru/HITACHI-HUH721212AL5204.htm',
#  'https://www.e-katalog.ru/SEAGATE-STEA2000431.htm',
#  'https://www.e-katalog.ru/A-DATA-AHD650-1TU3-CBK.htm',
#  'https://www.e-katalog.ru/WD-WDBYFT0020BBK.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST900MM0006.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST9300653SS.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST1000VN000.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST500LM000.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST4000NC001.htm',
#  'https://www.e-katalog.ru/NETAC-NT05K331N-002T-30BK.htm',
#  'https://www.e-katalog.ru/SEAGATE-STGD2000202.htm',
#  'https://www.e-katalog.ru/TOSHIBA-MK3276GSX.htm',
#  'https://www.e-katalog.ru/A-DATA-AHD710-2TU3.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST91000640NS.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST2000DL003.htm',
#  'https://www.e-katalog.ru/TOSHIBA-HDWA130EZSTA.htm',
#  'https://www.e-katalog.ru/WD-WD3200BPVT.htm',
#  'https://www.e-katalog.ru/SAMSUNG-HD103SJ.htm',
#  'https://www.e-katalog.ru/TOSHIBA-MG04ACA100N.htm',
#  'https://www.e-katalog.ru/HP-846524-B21.htm',
#  'https://www.e-katalog.ru/HP-512547-B21.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST9300605SS.htm',
#  'https://www.e-katalog.ru/HITACHI-HDS5C3030ALA630.htm',
#  'https://www.e-katalog.ru/HITACHI-HTS547550A9E384.htm',
#  'https://www.e-katalog.ru/A-DATA-AHD720-2TU3-CBK.htm',
#  'https://www.e-katalog.ru/TRANSCEND-TS500GSJ25M.htm',
#  'https://www.e-katalog.ru/WD-WD6001F9YZ.htm',
#  'https://www.e-katalog.ru/LACIE-STJJ5000400.htm',
#  'https://www.e-katalog.ru/SILICON-POWER-SP010TBPHDA15S3K.htm',
#  'https://www.e-katalog.ru/VERBATIM-53227.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST500LT012.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST31000340NS.htm',
#  'https://www.e-katalog.ru/HITACHI-HDS721010KLA330.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST1000NC001.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST900MP0146.htm',
#  'https://www.e-katalog.ru/TOSHIBA-AL14SEB030N.htm',
#  'https://www.e-katalog.ru/LENOVO-7XB7A00069.htm',
#  'https://www.e-katalog.ru/WD-WDBCRM0030BBK.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST9146803SS.htm',
#  'https://www.e-katalog.ru/TOSHIBA-AL13SEB300.htm',
#  'https://www.e-katalog.ru/HITACHI-HUC101812CSS204.htm',
#  'https://www.e-katalog.ru/LACIE-STHJ4000800.htm',
#  'https://www.e-katalog.ru/HITACHI-HDS721016CLA382.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST300MM0048.htm',
#  'https://www.e-katalog.ru/WD-WD10JUCT.htm',
#  'https://www.e-katalog.ru/SILICON-POWER-SP010TBPHDD06S3K.htm',
#  'https://www.e-katalog.ru/TOSHIBA-HDTC920EK3AA.htm',
#  'https://www.e-katalog.ru/LACIE-STHS8000800.htm',
#  'https://www.e-katalog.ru/VERBATIM-47683.htm',
#  'https://www.e-katalog.ru/WD-WD3001BKHG.htm',
#  'https://www.e-katalog.ru/HITACHI-HUC156060CSS204.htm',
#  'https://www.e-katalog.ru/HITACHI-HDN724030ALE640.htm',
#  'https://www.e-katalog.ru/HITACHI-HUC109090CSS600.htm',
#  'https://www.e-katalog.ru/HITACHI-HUA5C3030ALA640.htm',
#  'https://www.e-katalog.ru/HITACHI-HDS721010DLE630.htm',
#  'https://www.e-katalog.ru/WD-WDBLWE0040JCH.htm',
#  'https://www.e-katalog.ru/A-DATA-AHC660-1TU3-CGY.htm',
#  'https://www.e-katalog.ru/HP-454146-B21.htm',
#  'https://www.e-katalog.ru/HP-AP860A.htm',
#  'https://www.e-katalog.ru/SEAGATE-STGD2000203.htm',
#  'https://www.e-katalog.ru/LENOVO-45J7918.htm',
#  'https://www.e-katalog.ru/A-DATA-AHD680-1TU31-CBK.htm',
#  'https://www.e-katalog.ru/SEAGATE-STGD2000204.htm',
#  'https://www.e-katalog.ru/SEAGATE-STEA2000428.htm',
#  'https://www.e-katalog.ru/G-TECHNOLOGY-0G10264-1.htm',
#  'https://www.e-katalog.ru/SEAGATE-STSHX-M201TCBM.htm',
#  'https://www.e-katalog.ru/IBM-81Y9650.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST9146852SS.htm',
#  'https://www.e-katalog.ru/LACIE-STFS2000800.htm',
#  'https://www.e-katalog.ru/TOSHIBA-HDTH305ER3AB.htm',
#  'https://www.e-katalog.ru/TRANSCEND-TS1TSJ25C3N.htm',
#  'https://www.e-katalog.ru/TOSHIBA-MK1001TRKB.htm',
#  'https://www.e-katalog.ru/CISCO-A03-D1TBSATA.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST3250310CS.htm',
#  'https://www.e-katalog.ru/SAMSUNG-HM160HC.htm',
#  'https://www.e-katalog.ru/HP-655710-B21.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST1000NM0011.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST6000AS0002.htm',
#  'https://www.e-katalog.ru/WD-WD5002ABYS.htm',
#  'https://www.e-katalog.ru/WD-WD6000BLHX.htm',
#  'https://www.e-katalog.ru/SAMSUNG-HD502IJ.htm',
#  'https://www.e-katalog.ru/TOSHIBA-MG04ACA400A.htm',
#  'https://www.e-katalog.ru/HITACHI-HUS723030ALS640.htm',
#  'https://www.e-katalog.ru/HP-J9F42A.htm',
#  'https://www.e-katalog.ru/HP-LQ037AA.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST300MP0006.htm',
#  'https://www.e-katalog.ru/HP-605835-B21.htm',
#  'https://www.e-katalog.ru/DELL-400-ATJX.htm',
#  'https://www.e-katalog.ru/DELL-400-ASHI.htm',
#  'https://www.e-katalog.ru/A-DATA-AHV620S-1TU3-CBL.htm',
#  'https://www.e-katalog.ru/IBM-81Y9848.htm',
#  'https://www.e-katalog.ru/NETAC-NT05K338N-001T-30SL.htm',
#  'https://www.e-katalog.ru/WD-WDBP6A0020BBK.htm',
#  'https://www.e-katalog.ru/LENOVO-4XB0G45725.htm',
#  'https://www.e-katalog.ru/IBM-49Y6002.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST9600204SS.htm',
#  'https://www.e-katalog.ru/NETAC-NT05K330N-002T-30SL.htm',
#  'https://www.e-katalog.ru/HITACHI-HDS724040ALE640.htm',
#  'https://www.e-katalog.ru/HITACHI-HDP725050GLA360.htm',
#  'https://www.e-katalog.ru/SEAGATE-STEH1000200.htm',
#  'https://www.e-katalog.ru/FUJITSU-S26361-F3670-L400.htm',
#  'https://www.e-katalog.ru/WD-WD2002FYPS.htm',
#  'https://www.e-katalog.ru/HITACHI-HMS5C4040BLE640.htm',
#  'https://www.e-katalog.ru/HITACHI-HTS725032A9A364.htm',
#  'https://www.e-katalog.ru/HITACHI-HDS725050KLA360.htm',
#  'https://www.e-katalog.ru/TOSHIBA-MC04ACA400E.htm',
#  'https://www.e-katalog.ru/SEAGATE-STCK1000200.htm',
#  'https://www.e-katalog.ru/TOSHIBA-MK2002TSKB.htm',
#  'https://www.e-katalog.ru/HITACHI-HTS727550A9E364.htm',
#  'https://www.e-katalog.ru/WD-WD1500AHFD.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST9500620SS.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST32000641AS.htm',
#  'https://www.e-katalog.ru/WD-WD3200BEKT.htm',
#  'https://www.e-katalog.ru/LENOVO-7XB7A00025.htm',
#  'https://www.e-katalog.ru/FUJITSU-S26361-F3907-L200.htm',
#  'https://www.e-katalog.ru/TOSHIBA-AL14SXB60EN.htm',
#  'https://www.e-katalog.ru/NETAC-NT05K390K-002T-30BK.htm',
#  'https://www.e-katalog.ru/IBM-00Y2499.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST1200MM0088.htm',
#  'https://www.e-katalog.ru/IBM-49Y1866.htm',
#  'https://www.e-katalog.ru/WD-WD4NPURX.htm',
#  'https://www.e-katalog.ru/IBM-90Y8953.htm',
#  'https://www.e-katalog.ru/FUJITSU-S26361-F4005-L560.htm',
#  'https://www.e-katalog.ru/SEAGATE-ST3300656SS.htm',
#  'https://www.e-katalog.ru/LACIE-STGW4000800.htm',
#  'https://www.e-katalog.ru/TOSHIBA-AL14SEB12EQ.htm',
#  'https://www.e-katalog.ru/TOSHIBA-AL13SXB600N.htm',
#  'https://www.e-katalog.ru/HITACHI-HUA721010KLA330.htm',
#  'https://www.e-katalog.ru/HP-458924-B21.htm',
#  'https://www.e-katalog.ru/FUJITSU-S26361-F3708-L500.htm',
#  'https://www.e-katalog.ru/CISCO-A03-D300GA2.htm',
#  'https://www.e-katalog.ru/HITACHI-HDS5C4040ALE630.htm',
#  'https://www.e-katalog.ru/HITACHI-HDT721010SLA360.htm',
#  'https://www.e-katalog.ru/CISCO-A03-D500GC3.htm',
#  'https://www.e-katalog.ru/TOSHIBA-MBF245LRC.htm',
#  'https://www.e-katalog.ru/TOSHIBA-MK5061GSY.htm',
#  'https://www.e-katalog.ru/HITACHI-HTS545016B9A300.htm',
#  'https://www.e-katalog.ru/WD-WD3000BKFG.htm',
#  'https://www.e-katalog.ru/HP-R0Q53A.htm',
#  'https://www.e-katalog.ru/LENOVO-7XB7A00023.htm',
#  'https://www.e-katalog.ru/HP-R0Q55A.htm',
#  'https://www.e-katalog.ru/LENOVO-4XB7A14112.htm',
#  'https://www.e-katalog.ru/HP-R0Q58A.htm',
#  'https://www.e-katalog.ru/FUJITSU-S26361-F5636-L400.htm',
#  'https://www.e-katalog.ru/DELL-400-BDOZ.htm',
#  'https://www.e-katalog.ru/SILICON-POWER-SP020TBPHDD05S3T.htm',
#  'https://www.e-katalog.ru/HP-861683-B21.htm',
#  'https://www.e-katalog.ru/DELL-400-ASHF.htm',
#  'https://www.e-katalog.ru/HUAWEI-02311HAK.htm',
#  'https://www.e-katalog.ru/SEAGATE-STGD2000206.htm',
#  'https://www.e-katalog.ru/SEAGATE-STGD2000205.htm',
#  'https://www.e-katalog.ru/LENOVO-4XB7A13554.htm',
#  'https://www.e-katalog.ru/HUAWEI-02350SND.htm',
#  'https://www.e-katalog.ru/WD-WDBWLG0160HBK.htm',
#  'https://www.e-katalog.ru/APACER-AP1TBAC731B-1.htm',
#  'https://www.e-katalog.ru/HP-QR492A.htm',
#  'https://www.e-katalog.ru/HP-480942-002.htm',
#  'https://www.e-katalog.ru/APACER-AP1TBAC236B-1.htm',
#  'https://www.e-katalog.ru/APACER-AP1TBAC233B-S.htm',
#  'https://www.e-katalog.ru/VERBATIM-53237.htm',
#  'https://www.e-katalog.ru/LENOVO-4XB7A13555.htm',
#  'https://www.e-katalog.ru/SILICON-POWER-SP010TBPHD62SS3K.htm',
#  'https://www.e-katalog.ru/SILICON-POWER-SP010TBPHDD03S3K.htm',
#  'https://www.e-katalog.ru/LENOVO-7XB7A00051.htm',
#  'https://www.e-katalog.ru/HUAWEI-02311HAP.htm',
#  'https://www.e-katalog.ru/LACIE-STHY1000800.htm',
#  'https://www.e-katalog.ru/APACER-AP2TBAC632A-1.htm',
#  'https://www.e-katalog.ru/SILICON-POWER-SP020TBPHDD20S3W.htm',
#  'https://www.e-katalog.ru/LACIE-STFD1000400.htm',
#  'https://www.e-katalog.ru/A-DATA-AHD700-2TU3-CBK.htm',
#  'https://www.e-katalog.ru/VERBATIM-53150.htm',
#  'https://www.e-katalog.ru/TOSHIBA-HDTW130EBMCA.htm',
#  'https://www.e-katalog.ru/EMC-V2-PS07-020.htm',
#  'https://www.e-katalog.ru/HUAWEI-02310YCG.htm',
#  'https://www.e-katalog.ru/HITACHI-HUH728060ALE604.htm',
#  'https://www.e-katalog.ru/IBM-41Y8218.htm',
#  'https://www.e-katalog.ru/HP-AJ738A.htm',
#  'https://www.e-katalog.ru/CISCO-UCS-HDD1TI2F212.htm',
#  'https://www.e-katalog.ru/HITACHI-HDE721010SLA330.htm',
#  'https://www.e-katalog.ru/IBM-00Y2473.htm',
#  'https://www.e-katalog.ru/FUJITSU-S26361-F4482-L160.htm',
#  'https://www.e-katalog.ru/HITACHI-HCT721016SLA380.htm',
#  'https://www.e-katalog.ru/LENOVO-43R1990.htm',
#  'https://www.e-katalog.ru/SEAGATE-STCA2000200.htm',
#  'https://www.e-katalog.ru/HITACHI-HTS541075A9E680.htm',
#  'https://www.e-katalog.ru/HITACHI-HDS5C1050CLA382.htm',
#  'https://www.e-katalog.ru/HITACHI-HTS543232A7A384.htm']
